# %% [markdown]
# #### Investigating Airplane Accidents
# Using search algorithms and data structures to explore airplane accident data.

# %%
import pandas as pd
import numpy as np
import datetime
aviation_list =[]

# %%
with open("AviationData.txt",'r') as f:
    aviation_data = f.readlines()
    for line in aviation_data:
        lines_split = line.split('|')
        aviation_list.append([r.strip() for r in lines_split])

# %%
#Algorith should be modular and abstract
def linearsearch_code(code):
    lax_code=[] 
    for row in aviation_list:
        if code in row:
            lax_code.append(row)
    return lax_code

codes = linearsearch_code("LAX94LA336")
        
codes
# Out:
# [['20001218X45447',
#   'Accident',
#   'LAX94LA336',
#   '07/19/1962',
#   'BRIDGEPORT, CA',
#   'United States',
#   '',
#   '',
#   '',
#   '',
#   'Fatal(4)',
#   'Destroyed',
#   '',
#   'N5069P',
#   'PIPER',
#   'PA24-180',
#   'No',
#   '1',
#   'Reciprocating',
#   '',
#   '',
#   'Personal',
#   '',
#   '4',
#   '0',
#   '0',
#   '0',
#   'UNK',
#   'UNKNOWN',
#   'Probable Cause',
#   '09/19/1996',
#   '']]

# %% [markdown]
# #### Hash Tables
#
# Working with Hash Tables. Hash Tables is a data structure that stores data based on keys-value pairs.A dictionary is most common form of a hash table

# %%
aviation_dict_list= []
headers= aviation_data[0].split("|")
for i, line in enumerate(aviation_data):
    l = line.strip().split("|")
    d={k.strip():d.strip() for k,d in zip(headers, l)}
    aviation_dict_list.append(d)

# %%
lax_dict=[]
for d in aviation_dict_list:
    if "LAX94LA336" in d.values():
        lax_dict.append(d)    
        
lax_dict
# Out:
# [{'Event Id': '20001218X45447',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'LAX94LA336',
#   'Event Date': '07/19/1962',
#   'Location': 'BRIDGEPORT, CA',
#   'Country': 'United States',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Fatal(4)',
#   'Aircraft Damage': 'Destroyed',
#   'Aircraft Category': '',
#   'Registration Number': 'N5069P',
#   'Make': 'PIPER',
#   'Model': 'PA24-180',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': '',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '4',
#   'Total Serious Injuries': '0',
#   'Total Minor Injuries': '0',
#   'Total Uninjured': '0',
#   'Weather Condition': 'UNK',
#   'Broad Phase of Flight': 'UNKNOWN',
#   'Report Status': 'Probable Cause',
#   'Publication Date': '09/19/1996',
#   '': ''}]

# %% [markdown]
# Accessing and storing data in hash tables is very quick.however, using a hash table uses lot of memory

# %% [markdown]
# #### Accidents by U.S. State

# %% [markdown]
# ##### Count how many accidents happend in the U.S state

# %%
aviation_dict_list
# Out:
# [{'Event Id': 'Event Id',
#   'Investigation Type': 'Investigation Type',
#   'Accident Number': 'Accident Number',
#   'Event Date': 'Event Date',
#   'Location': 'Location',
#   'Country': 'Country',
#   'Latitude': 'Latitude',
#   'Longitude': 'Longitude',
#   'Airport Code': 'Airport Code',
#   'Airport Name': 'Airport Name',
#   'Injury Severity': 'Injury Severity',
#   'Aircraft Damage': 'Aircraft Damage',
#   'Aircraft Category': 'Aircraft Category',
#   'Registration Number': 'Registration Number',
#   'Make': 'Make',
#   'Model': 'Model',
#   'Amateur Built': 'Amateur Built',
#   'Number of Engines': 'Number of Engines',
#   'Engine Type': 'Engine Type',
#   'FAR Description': 'FAR Description',
#   'Schedule': 'Schedule',
#   'Purpose of Flight': 'Purpose of Flight',
#   'Air Carrier': 'Air Carrier',
#   'Total Fatal Injuries': 'Total Fatal Injuries',
#   'Total Serious Injuries': 'Total Serious Injuries',
#   'Total Minor Injuries': 'Total Minor Injuries',
#   'Total Uninjured': 'Total Uninjured',
#   'Weather Condition': 'Weather Condition',
#   'Broad Phase of Flight': 'Broad Phase of Flight',
#   'Report Status': 'Report Status',
#   'Publication Date': 'Publication Date',
#   '': ''},
#  {'Event Id': '20200707X80954',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20LA268',
#   'Event Date': '07/07/2020',
#   'Location': 'Buena Vista, CO',
#   'Country': 'United States',
#   'Latitude': '38.813611',
#   'Longitude': '-106.121389',
#   'Airport Code': 'AEJ',
#   'Airport Name': 'Central Colorado Regional',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'C-GTVS',
#   'Make': 'Mooney',
#   'Model': 'M20TN',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '1',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'TAKEOFF',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/09/2020',
#   '': ''},
#  {'Event Id': '20200705X11323',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR20CA207',
#   'Event Date': '07/05/2020',
#   'Location': 'Hondo, TX',
#   'Country': 'United States',
#   'Latitude': '29.359167',
#   'Longitude': '-99.177500',
#   'Airport Code': 'HDO',
#   'Airport Name': 'South Texas Rgnl At Hondo',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N997VB',
#   'Make': 'GRUMMAN',
#   'Model': 'AA-5B',
#   'Amateur Built': '',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/06/2020',
#   '': ''},
#  {'Event Id': '20200705X10100',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR20CA205',
#   'Event Date': '07/05/2020',
#   'Location': 'Sedona, AZ',
#   'Country': 'United States',
#   'Latitude': '34.848611',
#   'Longitude': '-111.788333',
#   'Airport Code': 'SEZ',
#   'Airport Name': 'Sedona',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N8868M',
#   'Make': 'Beech',
#   'Model': '23',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/06/2020',
#   '': ''},
#  {'Event Id': '20200706X45852',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20CA238',
#   'Event Date': '07/05/2020',
#   'Location': 'Easton, PA',
#   'Country': 'United States',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': 'N43',
#   'Airport Name': '',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N106G',
#   'Make': 'Socata',
#   'Model': 'TB 10',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/07/2020',
#   '': ''},
#  {'Event Id': '20200705X53746',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR20CA208',
#   'Event Date': '07/04/2020',
#   'Location': 'Neenah, WI',
#   'Country': 'United States',
#   'Latitude': '44.160000',
#   'Longitude': '-88.559444',
#   'Airport Code': '79C',
#   'Airport Name': 'Brennand',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N3440X',
#   'Make': 'Mooney',
#   'Model': 'M20E',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/06/2020',
#   '': ''},
#  {'Event Id': '20200707X53656',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ANC20CA066',
#   'Event Date': '07/04/2020',
#   'Location': 'Tyonek, AK',
#   'Country': 'United States',
#   'Latitude': '61.220000',
#   'Longitude': '152.160000',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': '',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N7208D',
#   'Make': 'Piper',
#   'Model': 'PA22',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/07/2020',
#   '': ''},
#  {'Event Id': '20200703X80212',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20LA260',
#   'Event Date': '07/03/2020',
#   'Location': "Port O'Conner, TX",
#   'Country': 'United States',
#   'Latitude': '28.445277',
#   'Longitude': '-96.441111',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N9891B',
#   'Make': 'Champion',
#   'Model': '7EC',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'MANEUVERING',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/07/2020',
#   '': ''},
#  {'Event Id': '20200705X05134',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR20CA204',
#   'Event Date': '07/02/2020',
#   'Location': 'San Diego, CA',
#   'Country': 'United States',
#   'Latitude': '32.815833',
#   'Longitude': '-117.139444',
#   'Airport Code': 'MYF',
#   'Airport Name': 'Montgomery-Gibbs Executive',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N3086W',
#   'Make': 'Cessna',
#   'Model': 'A185',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/06/2020',
#   '': ''},
#  {'Event Id': '20200702X70852',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20CA241',
#   'Event Date': '07/02/2020',
#   'Location': 'Clinton County, NY',
#   'Country': 'United States',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': '',
#   'Aircraft Category': '',
#   'Registration Number': 'N526MA',
#   'Make': 'Aviat',
#   'Model': 'A1',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/09/2020',
#   '': ''},
#  {'Event Id': '20200702X02853',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20CA239',
#   'Event Date': '07/02/2020',
#   'Location': 'Crystal River, FL',
#   'Country': 'United States',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': 'KCGC',
#   'Airport Name': '',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': '',
#   'Registration Number': 'N20131',
#   'Make': 'Beech',
#   'Model': '76',
#   'Amateur Built': 'No',
#   'Number of Engines': '2',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/09/2020',
#   '': ''},
#  {'Event Id': '20200701X01852',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20CA236',
#   'Event Date': '07/01/2020',
#   'Location': 'Meadville, PA',
#   'Country': 'United States',
#   'Latitude': '41.626667',
#   'Longitude': '-80.214722',
#   'Airport Code': 'GKJ',
#   'Airport Name': 'Port Meadville',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N9127H',
#   'Make': 'Cessna',
#   'Model': '172',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/08/2020',
#   '': ''},
#  {'Event Id': '20200701X35852',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20CA235',
#   'Event Date': '07/01/2020',
#   'Location': 'Chesapeake, VA',
#   'Country': 'United States',
#   'Latitude': '36.665000',
#   'Longitude': '-76.321111',
#   'Airport Code': 'CPK',
#   'Airport Name': 'Chesapeake Rgnl',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N9391H',
#   'Make': 'Cessna',
#   'Model': '172',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Instructional',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/09/2020',
#   '': ''},
#  {'Event Id': '20200702X00420',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20LA258',
#   'Event Date': '07/01/2020',
#   'Location': 'Bridgeport, TX',
#   'Country': 'United States',
#   'Latitude': '33.162778',
#   'Longitude': '-97.824167',
#   'Airport Code': 'XBP',
#   'Airport Name': 'Bridgeport Muni',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N6530W',
#   'Make': 'Piper',
#   'Model': 'PA28',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '3',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'MANEUVERING',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/06/2020',
#   '': ''},
#  {'Event Id': '20200701X52913',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20LA256',
#   'Event Date': '07/01/2020',
#   'Location': 'Round Rock, TX',
#   'Country': 'United States',
#   'Latitude': '30.559444',
#   'Longitude': '-97.704722',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Fatal(1)',
#   'Aircraft Damage': 'Destroyed',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N19AS',
#   'Make': 'Cessna',
#   'Model': '320',
#   'Amateur Built': 'No',
#   'Number of Engines': '2',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '1',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'MANEUVERING',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/09/2020',
#   '': ''},
#  {'Event Id': '20200702X04509',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ANC20CA063',
#   'Event Date': '07/01/2020',
#   'Location': 'Nikolai, AK',
#   'Country': 'United States',
#   'Latitude': '62.553056',
#   'Longitude': '-153.381945',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': '',
#   'Registration Number': 'N6252M',
#   'Make': 'Stinson',
#   'Model': '108',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/07/2020',
#   '': ''},
#  {'Event Id': '20200630X04906',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR20CA200',
#   'Event Date': '06/29/2020',
#   'Location': 'McMinnville, OR',
#   'Country': 'United States',
#   'Latitude': '45.194444',
#   'Longitude': '-123.136111',
#   'Airport Code': 'MMV',
#   'Airport Name': 'Mc Minnville Muni',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N998HG',
#   'Make': 'Vans',
#   'Model': 'RV-8',
#   'Amateur Built': 'Yes',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/30/2020',
#   '': ''},
#  {'Event Id': '20200629X31824',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20CA231',
#   'Event Date': '06/29/2020',
#   'Location': 'South Bay, FL',
#   'Country': 'United States',
#   'Latitude': '26.472778',
#   'Longitude': '-80.556944',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': '',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N42190',
#   'Make': 'Air Tractor',
#   'Model': 'AT502',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 137: Agricultural',
#   'Schedule': '',
#   'Purpose of Flight': 'Aerial Application',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/08/2020',
#   '': ''},
#  {'Event Id': '20200630X22651',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ANC20CA062',
#   'Event Date': '06/28/2020',
#   'Location': 'Juneau, AK',
#   'Country': 'United States',
#   'Latitude': '58.141389',
#   'Longitude': '-134.377223',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N153CC',
#   'Make': 'Cub Crafters',
#   'Model': 'CCK-1865',
#   'Amateur Built': 'Yes',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/07/2020',
#   '': ''},
#  {'Event Id': '20200627X60335',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20LA248',
#   'Event Date': '06/27/2020',
#   'Location': 'Zavalla, TX',
#   'Country': 'United States',
#   'Latitude': '31.187500',
#   'Longitude': '-94.340833',
#   'Airport Code': '',
#   'Airport Name': 'PRIVATE',
#   'Injury Severity': 'Fatal(1)',
#   'Aircraft Damage': 'Destroyed',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N315AM',
#   'Make': 'Piper',
#   'Model': 'PA32R',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '1',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': 'IMC',
#   'Broad Phase of Flight': 'APPROACH',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/30/2020',
#   '': ''},
#  {'Event Id': '20200629X55704',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20CA254',
#   'Event Date': '06/27/2020',
#   'Location': 'Erie, MI',
#   'Country': 'United States',
#   'Latitude': '41.776389',
#   'Longitude': '-83.446944',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N59262',
#   'Make': 'Volmer',
#   'Model': 'VJ22',
#   'Amateur Built': 'Yes',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '1',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'LANDING',
#   'Report Status': 'Factual',
#   'Publication Date': '07/06/2020',
#   '': ''},
#  {'Event Id': '20200627X12209',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20CA253',
#   'Event Date': '06/27/2020',
#   'Location': 'Davenport, IA',
#   'Country': 'United States',
#   'Latitude': '41.612500',
#   'Longitude': '-90.588333',
#   'Airport Code': 'DVN',
#   'Airport Name': 'Davenport Muni',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N18873',
#   'Make': 'Beech',
#   'Model': '23',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '3',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/30/2020',
#   '': ''},
#  {'Event Id': '20200625X00253',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR20LA196',
#   'Event Date': '06/25/2020',
#   'Location': 'Centerville, UT',
#   'Country': 'United States',
#   'Latitude': '40.779167',
#   'Longitude': '-111.895833',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Fatal(2)',
#   'Aircraft Damage': 'Destroyed',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N620AK',
#   'Make': 'KOSTRAZEWA ANDRE',
#   'Model': 'Sonex Light Sport',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '2',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'DESCENT',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/06/2020',
#   '': ''},
#  {'Event Id': '20200625X33153',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20LA229',
#   'Event Date': '06/25/2020',
#   'Location': 'Coconut Creek, FL',
#   'Country': 'United States',
#   'Latitude': '26.263611',
#   'Longitude': '-80.100000',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Helicopter',
#   'Registration Number': 'N5013G',
#   'Make': 'Bell',
#   'Model': '206',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Turbo Shaft',
#   'FAR Description': 'Part 133: Rotorcraft Ext. Load',
#   'Schedule': '',
#   'Purpose of Flight': 'External Load',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '1',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'MANEUVERING',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/10/2020',
#   '': ''},
#  {'Event Id': '20200625X32845',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20CA251',
#   'Event Date': '06/25/2020',
#   'Location': 'Minneapolis, MN',
#   'Country': 'United States',
#   'Latitude': '45.145277',
#   'Longitude': '-93.211944',
#   'Airport Code': 'ANE',
#   'Airport Name': 'Anoka County-Blaine Airport',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N951X',
#   'Make': 'SONEX',
#   'Model': 'ONEX',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/30/2020',
#   '': ''},
#  {'Event Id': '20200624X32607',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR20CA198',
#   'Event Date': '06/24/2020',
#   'Location': 'Yellow Pine, ID',
#   'Country': 'United States',
#   'Latitude': '45.150556',
#   'Longitude': '-114.999444',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N288BC',
#   'Make': 'Maule',
#   'Model': 'M7',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/29/2020',
#   '': ''},
#  {'Event Id': '20200625X45503',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR20CA195',
#   'Event Date': '06/24/2020',
#   'Location': 'Liberty, UT',
#   'Country': 'United States',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N18XX',
#   'Make': 'CAPELLA',
#   'Model': 'XLS',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '1',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/26/2020',
#   '': ''},
#  {'Event Id': '20200625X33702',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20WA246',
#   'Event Date': '06/24/2020',
#   'Location': 'Long Marston, United Kingdom',
#   'Country': 'United Kingdom',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Destroyed',
#   'Aircraft Category': 'Helicopter',
#   'Registration Number': 'N120HH',
#   'Make': 'Bell',
#   'Model': '407',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Turbo Shaft',
#   'FAR Description': 'Non-U.S., Commercial',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': '',
#   'Broad Phase of Flight': 'CRUISE',
#   'Report Status': 'Foreign',
#   'Publication Date': '',
#   '': ''},
#  {'Event Id': '20200624X64251',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20LA245',
#   'Event Date': '06/24/2020',
#   'Location': 'Winfield, TX',
#   'Country': 'United States',
#   'Latitude': '33.164167',
#   'Longitude': '-95.147500',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N958HP',
#   'Make': 'Cessna',
#   'Model': '182',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Aerial Observation',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '1',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'MANEUVERING',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/06/2020',
#   '': ''},
#  {'Event Id': '20200624X51155',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20CA247',
#   'Event Date': '06/24/2020',
#   'Location': 'Fredericksburg, TX',
#   'Country': 'United States',
#   'Latitude': '30.243333',
#   'Longitude': '-98.909167',
#   'Airport Code': 'T82',
#   'Airport Name': 'Gillespie County',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N97LL',
#   'Make': 'Cub Crafters Inc',
#   'Model': 'CC19-180',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'LANDING',
#   'Report Status': 'Factual',
#   'Publication Date': '06/29/2020',
#   '': ''},
#  {'Event Id': '20200623X42835',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20CA225',
#   'Event Date': '06/23/2020',
#   'Location': 'Hollywood, FL',
#   'Country': 'United States',
#   'Latitude': '26.001111',
#   'Longitude': '-80.240833',
#   'Airport Code': 'HWO',
#   'Airport Name': 'North Perry',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N5314M',
#   'Make': 'Cessna',
#   'Model': '152',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Instructional',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/26/2020',
#   '': ''},
#  {'Event Id': '20200623X62215',
#   'Investigation Type': '',
#   'Accident Number': 'CEN20CA244',
#   'Event Date': '06/23/2020',
#   'Location': 'Pisgah, IA',
#   'Country': 'United States',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': 'None',
#   'Airport Name': '',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N7764W',
#   'Make': 'COYOTE',
#   'Model': 'S-6ES',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/30/2020',
#   '': ''},
#  {'Event Id': '20200629X00312',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'GAA20WA112',
#   'Event Date': '06/22/2020',
#   'Location': 'Vereda Brisas de Guaiquitia, Colombia',
#   'Country': 'Colombia',
#   'Latitude': '4.168334',
#   'Longitude': '73.082223',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Fatal(1)',
#   'Aircraft Damage': 'Destroyed',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': '',
#   'Make': 'PIPER',
#   'Model': 'PA25',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Non-U.S., Non-Commercial',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '1',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': 'CRUISE',
#   'Report Status': 'Foreign',
#   'Publication Date': '',
#   '': ''},
#  {'Event Id': '20200622X43824',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20CA226',
#   'Event Date': '06/22/2020',
#   'Location': 'SHELBY, NC',
#   'Country': 'United States',
#   'Latitude': '35.254167',
#   'Longitude': '-81.525000',
#   'Airport Code': 'EHO',
#   'Airport Name': 'Shelby-Cleveland County Rgnl',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N1718Q',
#   'Make': 'Cessna',
#   'Model': '150',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'DESCENT',
#   'Report Status': 'Factual',
#   'Publication Date': '07/02/2020',
#   '': ''},
#  {'Event Id': '20200623X44811',
#   'Investigation Type': '',
#   'Accident Number': 'ERA20CA224',
#   'Event Date': '06/22/2020',
#   'Location': 'Burlington, VT',
#   'Country': 'United States',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': 'BTV',
#   'Airport Name': 'Burlington Intl',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N7955V',
#   'Make': 'Cessna',
#   'Model': '180',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/25/2020',
#   '': ''},
#  {'Event Id': '20200622X41554',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20CA223',
#   'Event Date': '06/22/2020',
#   'Location': 'Monroe, NC',
#   'Country': 'United States',
#   'Latitude': '34.998889',
#   'Longitude': '-80.644166',
#   'Airport Code': 'EQY',
#   'Airport Name': 'Charlotte-Monroe Executive',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N3681Z',
#   'Make': 'Piper',
#   'Model': 'PA18',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/07/2020',
#   '': ''},
#  {'Event Id': '20200622X30444',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20CA240',
#   'Event Date': '06/21/2020',
#   'Location': 'Sheffield, TX',
#   'Country': 'United States',
#   'Latitude': '30.653889',
#   'Longitude': '-101.787500',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Helicopter',
#   'Registration Number': 'N298TH',
#   'Make': 'Schweizer',
#   'Model': '269C',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Aerial Observation',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'MANEUVERING',
#   'Report Status': 'Factual',
#   'Publication Date': '06/24/2020',
#   '': ''},
#  {'Event Id': '20200622X74814',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20CA222',
#   'Event Date': '06/20/2020',
#   'Location': 'ELIZABETHTON, TN',
#   'Country': 'United States',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N3815Z',
#   'Make': 'Beech',
#   'Model': '77',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/23/2020',
#   '': ''},
#  {'Event Id': '20200622X23544',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20LA239',
#   'Event Date': '06/20/2020',
#   'Location': 'Millersport, OH',
#   'Country': 'United States',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': 'NONE',
#   'Airport Name': 'PRIVATE',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Destroyed',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N51033',
#   'Make': 'Cessna',
#   'Model': '150',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'TAKEOFF',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/29/2020',
#   '': ''},
#  {'Event Id': '20200622X22057',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20CA238',
#   'Event Date': '06/20/2020',
#   'Location': 'Cambridge, OH',
#   'Country': 'United States',
#   'Latitude': '39.975000',
#   'Longitude': '-81.577500',
#   'Airport Code': 'CDI',
#   'Airport Name': 'Cambridge Municipal Airport',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': '',
#   'Registration Number': 'N856L',
#   'Make': 'Great Lakes',
#   'Model': '2T 1A',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/30/2020',
#   '': ''},
#  {'Event Id': '20200622X32354',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20CA227',
#   'Event Date': '06/19/2020',
#   'Location': 'Churchville, MD',
#   'Country': 'United States',
#   'Latitude': '39.568334',
#   'Longitude': '-76.203056',
#   'Airport Code': '0W3',
#   'Airport Name': 'Harford County',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N21585',
#   'Make': 'CESSNA',
#   'Model': '172',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Instructional',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/25/2020',
#   '': ''},
#  {'Event Id': '20200622X11830',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20CA236',
#   'Event Date': '06/19/2020',
#   'Location': 'Martinton, IL',
#   'Country': 'United States',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': 'N/A',
#   'Airport Name': '',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': '244HW',
#   'Make': 'BELLANCA',
#   'Model': '1730A',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/24/2020',
#   '': ''},
#  {'Event Id': '20200618X91338',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR20LA187',
#   'Event Date': '06/18/2020',
#   'Location': 'Coeur D Alene, ID',
#   'Country': 'United States',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': 'COE',
#   'Airport Name': '',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N6602B',
#   'Make': 'Cessna',
#   'Model': '310',
#   'Amateur Built': 'No',
#   'Number of Engines': '2',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '3',
#   'Weather Condition': '',
#   'Broad Phase of Flight': 'LANDING',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/06/2020',
#   '': ''},
#  {'Event Id': '20200618X83813',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20LA220',
#   'Event Date': '06/18/2020',
#   'Location': 'Pikeville, NC',
#   'Country': 'United States',
#   'Latitude': '35.444722',
#   'Longitude': '-77.925000',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Fatal(1)',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Helicopter',
#   'Registration Number': 'N4QW',
#   'Make': 'Robinson',
#   'Model': 'R66',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Turbo Shaft',
#   'FAR Description': 'Part 137: Agricultural',
#   'Schedule': '',
#   'Purpose of Flight': 'Aerial Application',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '1',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'MANEUVERING',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/06/2020',
#   '': ''},
#  {'Event Id': '20200618X72422',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR20WA186',
#   'Event Date': '06/17/2020',
#   'Location': 'Gauteng, South Africa',
#   'Country': 'South Africa',
#   'Latitude': '-25.986111',
#   'Longitude': '28.136389',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Fatal(2)',
#   'Aircraft Damage': 'Destroyed',
#   'Aircraft Category': 'Helicopter',
#   'Registration Number': '',
#   'Make': 'BELL',
#   'Model': '206',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '2',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': 'LANDING',
#   'Report Status': 'Foreign',
#   'Publication Date': '',
#   '': ''},
#  {'Event Id': '20200617X70035',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR20CA185',
#   'Event Date': '06/17/2020',
#   'Location': 'Clovis, NM',
#   'Country': 'United States',
#   'Latitude': '34.426667',
#   'Longitude': '-103.077500',
#   'Airport Code': 'CVN',
#   'Airport Name': 'Clovis Muni',
#   'Injury Severity': 'Unavailable',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N1407W',
#   'Make': 'Vans',
#   'Model': 'RV 6',
#   'Amateur Built': 'Yes',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/19/2020',
#   '': ''},
#  {'Event Id': '20200618X13408',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA20LA219',
#   'Event Date': '06/17/2020',
#   'Location': 'McAlpin, FL',
#   'Country': 'United States',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': 'FL10',
#   'Airport Name': 'Little River Airport',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N25449',
#   'Make': 'Cessna',
#   'Model': '152',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'TAKEOFF',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/29/2020',
#   '': ''},
#  {'Event Id': '20200622X10103',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20WA237',
#   'Event Date': '06/17/2020',
#   'Location': 'Reinsfeld, Germany',
#   'Country': 'Germany',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Fatal(1)',
#   'Aircraft Damage': 'Destroyed',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': '',
#   'Make': 'PIPER',
#   'Model': 'PA34',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Non-U.S., Non-Commercial',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '1',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': 'CRUISE',
#   'Report Status': 'Foreign',
#   'Publication Date': '',
#   '': ''},
#  {'Event Id': '20200618X02326',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20LA234',
#   'Event Date': '06/17/2020',
#   'Location': 'Pine Bluff, AR',
#   'Country': 'United States',
#   'Latitude': '34.206667',
#   'Longitude': '-91.873889',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Destroyed',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N1532H',
#   'Make': 'AIR TRACTOR',
#   'Model': 'AT402',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': 'Turbo Prop',
#   'FAR Description': 'Part 137: Agricultural',
#   'Schedule': '',
#   'Purpose of Flight': 'Aerial Application',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '1',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'UNKNOWN',
#   'Report Status': 'Preliminary',
#   'Publication Date': '07/09/2020',
#   '': ''},
#  {'Event Id': '20200619X12749',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20CA235',
#   'Event Date': '06/17/2020',
#   'Location': 'Gypsom, CO',
#   'Country': 'United States',
#   'Latitude': '39.640555',
#   'Longitude': '-106.909722',
#   'Airport Code': 'EGE',
#   'Airport Name': 'Eagle County Rgnl',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N339KT',
#   'Make': 'Cub Crafters',
#   'Model': 'CCX-2000-0086',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': '',
#   'Report Status': 'Preliminary',
#   'Publication Date': '06/30/2020',
#   '': ''},
#  {'Event Id': '20200617X61630',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN20CA233',
#   'Event Date': '06/17/2020',
#   'Location': 'Mount Victory, OH',
#   'Country': 'United States',
#   'Latitude': '40.372223',
#   'Longitude': '-83.511667',
#   'Airport Code': 'O74',
#   'Airport Name': 'Elliotts Landing',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N25702',
#   'Make': 'Piper',
#   'Model': 'J3C-65',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
# ...
#   'Airport Code': 'LCH',
#   'Airport Name': '',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N200Z',
#   'Make': 'Cirrus',
#   'Model': 'SR20',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'CRUISE',
#   'Report Status': 'Preliminary',
#   'Publication Date': '10/17/2019',
#   '': ''},
#  {'Event Id': '20190914X53757',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR19LA259',
#   'Event Date': '09/13/2019',
#   'Location': 'Marana, AZ',
#   'Country': 'United States',
#   'Latitude': '32.403889',
#   'Longitude': '-111.219723',
#   'Airport Code': 'AVQ',
#   'Airport Name': 'Marana Regional Airport',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N4403Z',
#   'Make': 'Piper',
#   'Model': 'PA28',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Instructional',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '3',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'STANDING',
#   'Report Status': 'Preliminary',
#   'Publication Date': '10/07/2019',
#   '': ''},
#  {'Event Id': '20191202X01410',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'GAA19WA595',
#   'Event Date': '09/13/2019',
#   'Location': 'Rio Verda, GO, Brazil',
#   'Country': 'Brazil',
#   'Latitude': '-17.852500',
#   'Longitude': '-50.952222',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Fatal(2)',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': '',
#   'Make': 'COZY',
#   'Model': 'Mark IV',
#   'Amateur Built': '',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Non-U.S., Non-Commercial',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '2',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': '',
#   'Broad Phase of Flight': 'TAKEOFF',
#   'Report Status': 'Foreign',
#   'Publication Date': '',
#   '': ''},
#  {'Event Id': '20190913X95610',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'GAA19CA545',
#   'Event Date': '09/13/2019',
#   'Location': 'Caldwell, ID',
#   'Country': 'United States',
#   'Latitude': '43.725556',
#   'Longitude': '-116.866945',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N4746F',
#   'Make': 'Cessna',
#   'Model': 'P206',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'LANDING',
#   'Report Status': 'Probable Cause',
#   'Publication Date': '03/17/2020',
#   '': ''},
#  {'Event Id': '20200212X20909',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA19CA291',
#   'Event Date': '09/13/2019',
#   'Location': 'Sebring, FL',
#   'Country': 'United States',
#   'Latitude': '27.456389',
#   'Longitude': '-81.342500',
#   'Airport Code': 'SEF',
#   'Airport Name': 'Sebring Rgnl',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N854T',
#   'Make': 'Beech',
#   'Model': '55',
#   'Amateur Built': 'No',
#   'Number of Engines': '2',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'LANDING',
#   'Report Status': 'Probable Cause',
#   'Publication Date': '06/16/2020',
#   '': ''},
#  {'Event Id': '20190915X91550',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN19LA320',
#   'Event Date': '09/13/2019',
#   'Location': 'Hoagland, IN',
#   'Country': 'United States',
#   'Latitude': '40.924445',
#   'Longitude': '-85.017223',
#   'Airport Code': 'FWA',
#   'Airport Name': 'FORT WAYNE INTL',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N578SP',
#   'Make': 'Cirrus',
#   'Model': 'SR22',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '2',
#   'Total Uninjured': '',
#   'Weather Condition': 'IMC',
#   'Broad Phase of Flight': 'CRUISE',
#   'Report Status': 'Preliminary',
#   'Publication Date': '09/25/2019',
#   '': ''},
#  {'Event Id': '20191010X13449',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR19WA275',
#   'Event Date': '09/12/2019',
#   'Location': 'Nanded, India',
#   'Country': 'India',
#   'Latitude': '',
#   'Longitude': '',
#   'Airport Code': '',
#   'Airport Name': '',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Minor',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': '',
#   'Make': 'CESSNA',
#   'Model': '525',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Non-U.S., Non-Commercial',
#   'Schedule': '',
#   'Purpose of Flight': '',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '8',
#   'Weather Condition': '',
#   'Broad Phase of Flight': 'LANDING',
#   'Report Status': 'Foreign',
#   'Publication Date': '',
#   '': ''},
#  {'Event Id': '20190912X81942',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR19LA257',
#   'Event Date': '09/12/2019',
#   'Location': 'Good Springs, NV',
#   'Country': 'United States',
#   'Latitude': '35.908056',
#   'Longitude': '-115.435000',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Balloon',
#   'Registration Number': 'N505CZ',
#   'Make': 'Kubicek',
#   'Model': 'BB60',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Aerial Observation',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '3',
#   'Total Minor Injuries': '6',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'LANDING',
#   'Report Status': 'Preliminary',
#   'Publication Date': '11/13/2019',
#   '': ''},
#  {'Event Id': '20190912X05539',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'GAA19CA544',
#   'Event Date': '09/12/2019',
#   'Location': 'Hemet, CA',
#   'Country': 'United States',
#   'Latitude': '33.727778',
#   'Longitude': '-117.030556',
#   'Airport Code': 'HMT',
#   'Airport Name': 'Hemet-Ryan',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N5229F',
#   'Make': 'Cessna',
#   'Model': '172F',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Public Aircraft',
#   'Schedule': '',
#   'Purpose of Flight': 'Instructional',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'LANDING',
#   'Report Status': 'Probable Cause',
#   'Publication Date': '03/17/2020',
#   '': ''},
#  {'Event Id': '20190912X15638',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'GAA19CA543',
#   'Event Date': '09/12/2019',
#   'Location': 'Memphis, TN',
#   'Country': 'United States',
#   'Latitude': '35.201111',
#   'Longitude': '-90.053889',
#   'Airport Code': 'M01',
#   'Airport Name': 'GENERAL DEWITT SPAIN',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N21979',
#   'Make': 'Cessna',
#   'Model': '150',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Instructional',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'LANDING',
#   'Report Status': 'Probable Cause',
#   'Publication Date': '02/11/2020',
#   '': ''},
#  {'Event Id': '20190912X11044',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'GAA19CA542',
#   'Event Date': '09/12/2019',
#   'Location': 'Phoenix, AZ',
#   'Country': 'United States',
#   'Latitude': '33.688333',
#   'Longitude': '-112.082500',
#   'Airport Code': 'DVT',
#   'Airport Name': 'Phoenix Deer Valley',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N796WW',
#   'Make': 'Cessna',
#   'Model': '172',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Instructional',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'TAKEOFF',
#   'Report Status': 'Probable Cause',
#   'Publication Date': '03/17/2020',
#   '': ''},
#  {'Event Id': '20190912X74625',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA19LA279',
#   'Event Date': '09/12/2019',
#   'Location': 'Charlotte Amalie, VI',
#   'Country': 'United States',
#   'Latitude': '18.337500',
#   'Longitude': '-64.967223',
#   'Airport Code': 'TIST',
#   'Airport Name': 'Cyril E King',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N269KW',
#   'Make': 'Piper',
#   'Model': 'PA23',
#   'Amateur Built': 'No',
#   'Number of Engines': '2',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'TAXI',
#   'Report Status': 'Factual',
#   'Publication Date': '06/03/2020',
#   '': ''},
#  {'Event Id': '20190912X21218',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'ERA19LA269',
#   'Event Date': '09/12/2019',
#   'Location': 'Bowie, MD',
#   'Country': 'United States',
#   'Latitude': '38.945000',
#   'Longitude': '-76.773334',
#   'Airport Code': 'W00',
#   'Airport Name': 'Freeway',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N202JB',
#   'Make': 'Mooney',
#   'Model': 'M20J',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '2',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'TAKEOFF',
#   'Report Status': 'Factual',
#   'Publication Date': '05/22/2020',
#   '': ''},
#  {'Event Id': '20190912X71702',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN19LA318',
#   'Event Date': '09/12/2019',
#   'Location': 'Hill City, SD',
#   'Country': 'United States',
#   'Latitude': '43.932500',
#   'Longitude': '-103.583611',
#   'Airport Code': 'N/A',
#   'Airport Name': '',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Helicopter',
#   'Registration Number': 'N100CK',
#   'Make': 'Bell',
#   'Model': '206',
#   'Amateur Built': 'No',
#   'Number of Engines': '',
#   'Engine Type': '',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '2',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'MANEUVERING',
#   'Report Status': 'Preliminary',
#   'Publication Date': '10/17/2019',
#   '': ''},
#  {'Event Id': '20190912X21831',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'CEN19LA316',
#   'Event Date': '09/12/2019',
#   'Location': 'Eustace, TX',
#   'Country': 'United States',
#   'Latitude': '32.276667',
#   'Longitude': '-96.006667',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Fatal(1)',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Powered Parachute',
#   'Registration Number': 'N6035L',
#   'Make': 'Infinity Power Parachutes',
#   'Model': 'IPP2',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Personal',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '1',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'CRUISE',
#   'Report Status': 'Preliminary',
#   'Publication Date': '09/18/2019',
#   '': ''},
#  {'Event Id': '20190911X73205',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'WPR19LA255',
#   'Event Date': '09/11/2019',
#   'Location': 'Azusa, CA',
#   'Country': 'United States',
#   'Latitude': '34.123889',
#   'Longitude': '-117.898611',
#   'Airport Code': '',
#   'Airport Name': 'N/A',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Helicopter',
#   'Registration Number': 'N1168U',
#   'Make': 'Sikorsky',
#   'Model': 'S58',
#   'Amateur Built': 'No',
#   'Number of Engines': '1',
#   'Engine Type': 'Turbo Shaft',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Positioning',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'CRUISE',
#   'Report Status': 'Preliminary',
#   'Publication Date': '09/25/2019',
#   '': ''},
#  {'Event Id': '20191127X60120',
#   'Investigation Type': 'Accident',
#   'Accident Number': 'GAA19CA596',
#   'Event Date': '09/11/2019',
#   'Location': 'Reno, NV',
#   'Country': 'United States',
#   'Latitude': '39.668056',
#   'Longitude': '-119.876389',
#   'Airport Code': 'RTS',
#   'Airport Name': 'Reno/Stead',
#   'Injury Severity': 'Non-Fatal',
#   'Aircraft Damage': 'Substantial',
#   'Aircraft Category': 'Airplane',
#   'Registration Number': 'N515JD',
#   'Make': 'Pitts',
#   'Model': 'S1',
#   'Amateur Built': 'Yes',
#   'Number of Engines': '1',
#   'Engine Type': 'Reciprocating',
#   'FAR Description': 'Part 91: General Aviation',
#   'Schedule': '',
#   'Purpose of Flight': 'Air Race/Show',
#   'Air Carrier': '',
#   'Total Fatal Injuries': '',
#   'Total Serious Injuries': '',
#   'Total Minor Injuries': '',
#   'Total Uninjured': '1',
#   'Weather Condition': 'VMC',
#   'Broad Phase of Flight': 'LANDING',
#   'Report Status': 'Probable Cause',
#   'Publication Date': '03/17/2020',
#   '': ''},
#  ...]

# %%
from collections import Counter
states=[]
for r in aviation_dict_list:
    if r["Country"] == "United States" and ',' in r["Location"]:
        state = r["Location"].split(',')[1].strip()
        if len(state)==2:
            states.append(state)
            
state_accidents = Counter(states)
state_accidents.most_common(5)
# Out:
# [('CA', 8654), ('TX', 5666), ('FL', 5634), ('AK', 5470), ('AZ', 2736)]

# %%
#sorted(state_accidents.items(), key=lambda pair: pair[1], reverse=True)

# %% [markdown]
# California and texas are these states are having most aviation accidents

# %% [markdown]
# ##### Fatalities and Injuries by Month

# %%
month_names = []
for dictionary in aviation_dict_list:
    month_injuries = []
    if 'Event Date' in dictionary:
        split_date = dictionary['Event Date'].split('/')
        try:
            s_injuries = int(dictionary['Total Serious Injuries'])
        except:
            s_injuries = 0
        try:
            f_injuries = int(dictionary['Total Fatal Injuries'])
        except:
            f_injuries = 0
        try:
            MM_YYYY = split_date[0]+'/'+split_date[2]
        except:
            MM_YYYY = ""
        if len(MM_YYYY) == 7:
            month_injuries.append(MM_YYYY)
            month_injuries.append(s_injuries)
            month_injuries.append(f_injuries)
    month_names.append(month_injuries)

# %%
from collections import OrderedDict

monthly_injuries = {}
for accident in month_names:
    try:
        month = accident[0]
        s_injury = accident[1]
        f_injury = accident[2]
    except:
        continue
    if month not in monthly_injuries:
        monthly_injuries[month] = {'Serious Injury': s_injury, 'Fatal Injury': f_injury}
    if month in monthly_injuries:
        monthly_injuries[month]['Serious Injury'] += s_injury
        monthly_injuries[month]['Fatal Injury'] += f_injury

injuries_count = Counter(monthly_injuries) 
OrderedDict(sorted(injuries_count.items(), key=lambda t: t[0]))bb

# %% [markdown]
# counting number of accidents by air carriers

# %%
air_carriers = []
for c in aviation_dict_list:
    air_carrier = c["Air Carrier"].split(",")
    if air_carrier != '':
        air_carr = c['Air Carrier']
        air_carriers.append(air_carr)
        
count = Counter(air_carriers)
print(count.most_common(4))
